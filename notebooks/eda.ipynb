# %%
import pandas as pd

# Load the CSV
df = pd.read_csv("../data/cleaned/deaths_clean.csv")

# 1) Value counts of profession column
print("Profession Value Counts:")
print(df["profession"].value_counts())

# 2) First 10 rows
print("\nFirst 10 Rows:")
print(df.head(10))

# 3) Number of rows with null age_at_death
null_age_count = df["age_at_death"].isna().sum()

print("\nRows with null age_at_death:")
print(null_age_count)
# Out:
# Profession Value Counts:
# profession
# Athlete       31755
# Politician    31536
# Actor         18737
# Scientist     16601
# Musician      13023
# Business       4808
# Royalty         779
# Name: count, dtype: int64
#
# First 10 Rows:
#                                                 name        date  \
# 0                                    Larry Bearnarth  2000-01-01
# 1                                     Maurice Hallam  2000-01-01
# 2                                        Dick Pabich  2000-01-01
# 3                                       Stan Patrick  2000-01-01
# 4                                   Gerda Paumgarten  2000-01-01
# 5                                      Liu Songsheng  2000-01-01
# 6                                     Andy Spognardi  2000-01-01
# 7                                      Colin Vaughan  2000-01-01
# 8                                       Nat Adderley  2000-01-02
# 9  Princess María de las Mercedes of Bourbon-Two ...  2000-01-02
#
# ...
